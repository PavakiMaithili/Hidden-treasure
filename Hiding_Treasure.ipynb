# %%
pos=[" "," A","  B","  C"]
line1=["1","|_|","|_|","|_|"]
line2=["2","|_|","|_|","|_|"]
line3=["3","|_|","|_|","|_|"]
map=[pos,line1,line2,line3]
print("Specify the location where you want to hide your treasure in the given spaces")
print(f"{pos}\n{line1}\n{line2}\n{line3}")
p=input()
abc=["A","B","C"]
p1=abc.index(p[0])+1
num=int(p[1])
map[num][p1]="X"
print("Your treasure is hidden here")
print(f"{pos}\n{line1}\n{line2}\n{line3}")
# Out:
# Specify the location where you want to hide your treasure in the given spaces
# [' ', ' A', '  B', '  C']
# ['1', '|_|', '|_|', '|_|']
# ['2', '|_|', '|_|', '|_|']
# ['3', '|_|', '|_|', '|_|']
#  C3
# Your treasure is hidden here
# [' ', ' A', '  B', '  C']
# ['1', '|_|', '|_|', '|_|']
# ['2', '|_|', '|_|', '|_|']
# ['3', '|_|', '|_|', 'X']
